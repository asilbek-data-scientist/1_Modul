# %% [markdown]
# <a href="https://colab.research.google.com/github/asilbek-data-scientist/1_Modul/blob/main/3_modul_Ma'lumotlarbnishlash_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv #githubdagi bitta fileni chaqirib olish
# Out:
# --2022-10-18 04:52:11--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv.1’
#
# merc.csv.1          100%[===================>] 710.98K  --.-KB/s    in 0.03s
#
# 2022-10-18 04:52:11 (22.7 MB/s) - ‘merc.csv.1’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv('merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df1 = pd.read_csv('sample_data/california_housing_test.csv')
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df3 = pd.read_excel('uzbekistan.xlsx', index_col=0)
df3.head()
# Out:
#                    Maydoni (kv.km)  Aholisi
# Boʻlinishi
# Andijon viloyati              4200  1899000
# Buxoro viloyati              39400  1384700
# Fargʻona viloyati             6800  2597000
# Jizzax viloyati              20500   910500
# Xorazm viloyati               6300  1200000

# %%
df3.to_csv('newuzb.csv')

# %%
obj = df3.Aholisi
obj
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %%
obj.to_csv('old.csv')

# %%
open_old = pd.read_csv('old.csv', index_col='Boʻlinishi', squeeze=True) #squeeze bn series ko'rinishida ochiladi.
open_old
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %%
df.to_excel('merc2.xlsx')

# %%
df.to_excel('merc3.xlsx', index=False)

# %%
df.to_excel('merc4.xlsx', index=False, columns=['model', 'year', 'fuelType', 'tax'])

# %% [markdown]
# HDF5 formati

# %%
hdfobj = pd.HDFStore("data.h5") #HDFStore bir nechta datani siqib saqlaydi.

# %%
hdfobj.put('uzdata', df3)

# %%
hdfobj.put('cardata', df)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/pop', '/uzdata']

# %%
hdfobj['cardata'].head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
hdfobj.close()

# %%
newhdf = pd.HDFStore("data.h1")

# %%
newhdf.put('ol', df1)

# %%
newhdf.put('ber', df3)

# %%
newhdf.keys()
# Out:
# ['/ber', '/ol']

# %%
hdfobj.close()

# %%
hdfobj.keys()
# Out:
# ['/pop']

# %%
data = pd.read_hdf('data.h5', key='pop')# datani chaqirib oqitadi
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-8ee65a6738a4> in <module>
# ----> 1 data = pd.read_hdf('data.h5', key='pop')# datani chaqirib oqitadi
#       2 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     427             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     428
# --> 429         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     430         # can't auto open/close if we are using an iterator
#     431         # so delegate to the iterator
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     589         self._fletcher32 = fletcher32
#     590         self._filters = None
# ...

# %%
hdfobj = pd.HDFStore("data.h2")# HDFStore yangi papka ochadi

# %%
hdfobj.put('pop', df1)# shu papkaga data put qiladi

# %%
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
hdfobj.keys()
# Out:
# ['/pop']

# %%
df.to_hdf('uzdata.h5',key='uzdata')

# %% [markdown]
# Web sahifalardan o'qish

# %%
tashkent = pd.read_html('https://en.wikipedia.org/wiki/Tashkent')

# %%
len(tashkent)
# Out:
# 17

# %%
tashkent[5]
# Out:
#    Climate data for Tashkent (1981–2010, extremes 1881–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                                Average high °C (°F)
# 2                                  Daily mean °C (°F)
# 3                                 Average low °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                          Average precipitation days
# 7                                  Average snowy days
# 8                       Average relative humidity (%)
# 9                         Mean monthly sunshine hours
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jan
# 0                                          22.6(72.7)
# ...

# %% [markdown]
# JSON filelarni ochish

# %%
import pandas as pd
import json

# %%
#df = pd.read_json('sample2.json')
#data = pd.read_json('sample2.json')

df = pd.DataFrame(json.sample2.json)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-cbf58d9e7fcf> in <module>
#       2 #data = pd.read_json('sample2.json')
#       3
# ----> 4 df = pd.DataFrame(json.sample2.json)
#       5 df
#
# AttributeError: module 'json' has no attribute 'sample2'

# %%
df = pd.read_json('universities_ranking.json')
df
# Out:
#                                                title        location  \
# 0                               University of Oxford  United Kingdom
# 1                                Stanford University   United States
# 2                                 Harvard University   United States
# 3                 California Institute of Technology   United States
# 4              Massachusetts Institute of Technology   United States
# ...                                              ...             ...
# 1521                              Yuan Ze University          Taiwan
# 1522  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523                              Zagazig University           Egypt
# 1524                            University of Zagreb         Croatia
# 1525                            University of Žilina        Slovakia
#
#      number students  students staff ratio perc intl students gender ratio
# ...
