# %% [markdown]
# <a href="https://colab.research.google.com/github/asilbek-data-scientist/1_Modul/blob/main/3_modul_Ma'lumotlarnitayyorlash_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.isnull().sum() # har bir ustundagi nan qiymatlar
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        46 non-null     float64
#  3   length            48 non-null     float64
#  4   engine-type       49 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        45 non-null     float64
#  7   average-mileage   46 non-null     float64
#  8   price             58 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 4.8+ KB

# %%
len(df)
# Out:
# 61

# %%
round(df.isnull().sum() /len(df) *100)
# Out:
# company              0.0
# body-style           0.0
# wheel-base          25.0
# length              21.0
# engine-type         20.0
# num-of-cylinders     0.0
# horsepower          26.0
# average-mileage     25.0
# price                5.0
# dtype: float64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna())
# Out:
# 14

# %%
df.dropna(axis=1)# nan bo'lgan ustunlarni tashlab yuboradi.
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48)# nan ustunlarni tashla lekin ustunda 48 tadan ko'p data bo'lsa qoldir.
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %%
df.dropna(subset=['price', 'horsepower'], inplace=True) # price va horsepowerdagi nan qiymatlar bor qatorlarni tashlab yubor.

# %%
df.shape
# Out:
# (43, 9)

# %%
df.shape
# Out:
# (43, 9)

# %%
df.fillna(100).head() #barcha nan qiymatlarni 100 bn to'ldirish
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible       100.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0            100.0  16500.0
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0

# %%
df.fillna({'average-mileage':90}).head() # belgilangan ustundagi nan qiymatlarni 90 bn almashtiradi.
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0             90.0  16500.0
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0

# %%
mean1 = np.mean(df['wheel-base'])

# %%
df.fillna({'wheel-base': mean1}).head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible   99.843333   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 5             audi        sedan   99.800000   177.3         ohc
# 6             audi        wagon  105.800000   192.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 5                 five       110.0             19.0  15250.0
# 6                 five       110.0             19.0  18920.0

# %%
df.fillna(method='bfill') # nan qiymatni ozidan keyingi raqam bn to'ldiradi.
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 1        alfa-romero  convertible        94.5   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 10               bmw        sedan       101.2   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 14               bmw        sedan       103.5   197.0         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 17         chevrolet    hatchback        94.5   155.9         ohc
# 18         chevrolet        sedan        93.7   158.8         ohc
# 19             dodge    hatchback        93.7   157.3         ohc
# 20             dodge    hatchback        93.7   175.4         ohc
# ...

# %%
df.fillna(method="ffill").tail()
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 79         toyota      wagon       104.5   187.8        dohc              six
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
# 87          volvo      sedan       104.3   188.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 79          156.0             27.0  15750.0
# 81           85.0             27.0   7975.0
# 82           52.0             37.0   7995.0
# 86          100.0             37.0   9995.0
# 87          114.0             23.0  12940.0

# %%
df[df.company == 'toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback         NaN   158.7         ohc             four
# 68     toyota  hatchback         NaN   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7     NaN         NaN             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 79          156.0              NaN  15750.0

# %%
df[df.company == "toyota"].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   187.8        dohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 79          156.0              NaN  15750.0

# %%
df.fillna(df.mean()).head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible   99.843333   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 5             audi        sedan   99.800000   177.3         ohc
# 6             audi        wagon  105.800000   192.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four       111.0        21.000000  16500.0
# 2                  six       154.0        24.757576  16500.0
# ...

# %%
mean_1 = df[df['body-style'] == 'hatchback']
mean_1
# Out:
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5   171.2        ohcv
# 17       chevrolet  hatchback        94.5   155.9         ohc
# 19           dodge  hatchback        93.7   157.3         ohc
# 20           dodge  hatchback        93.7     NaN         ohc
# 37           mazda  hatchback        93.1   159.1         ohc
# 38           mazda  hatchback        93.1   159.1         ohc
# 39           mazda  hatchback         NaN     NaN         NaN
# 50      mitsubishi  hatchback        93.7     NaN         NaN
# 66          toyota  hatchback         NaN   158.7         ohc
# 68          toyota  hatchback         NaN   158.7         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 2                  six       154.0              NaN  16500.0
# 17                four        70.0             38.0   6295.0
# 19                four        68.0             31.0   6377.0
# ...

# %%
mean_1.fillna(mean_1.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback   94.500000   171.2        ohcv
# 17       chevrolet  hatchback   94.500000   155.9         ohc
# 19           dodge  hatchback   93.700000   157.3         ohc
# 20           dodge  hatchback   93.700000   160.0         ohc
# 37           mazda  hatchback   93.100000   159.1         ohc
# 38           mazda  hatchback   93.100000   159.1         ohc
# 39           mazda  hatchback   93.757143   160.0         NaN
# 50      mitsubishi  hatchback   93.700000   160.0         NaN
# 66          toyota  hatchback   93.757143   158.7         ohc
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv')
df.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
df.shape
# Out:
# (247, 6)

# %%
df.duplicated().sum()
# Out:
# 15

# %%
df.drop_duplicates()
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df.drop_duplicates(['country'])
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict = {'four':4, 'six':6, 'five':5, 'three':3,  'twelve':12, 'two':2, 'eight':8}
df['cylinders'] = df['num-of-cylinders'].map(dict)
df.drop('num-of-cylinders', axis=1)
# Out:
#            company   body-style  wheel-base  length engine-type  horsepower  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc         NaN
# 1      alfa-romero  convertible         NaN   168.8        dohc       111.0
# 2      alfa-romero    hatchback        94.5   171.2        ohcv       154.0
# 3             audi        sedan        99.8   176.6         ohc       102.0
# 4             audi        sedan        99.4   176.6         ohc         NaN
# ...            ...          ...         ...     ...         ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc        85.0
# 82      volkswagen        sedan         NaN   171.7         NaN        52.0
# 86      volkswagen        sedan        97.3     NaN         ohc       100.0
# 87           volvo        sedan       104.3   188.8         NaN       114.0
# 88           volvo        wagon       104.3   188.8         ohc         NaN
#
#        average-mileage    price  cylinders
# ...

# %%
kurs = 11011
df['preice_uz'] = df['price'].map(lambda x: x*kurs)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# 1                 four       111.0             21.0  16500.0          4
# 2                  six       154.0              NaN  16500.0          6
# 3                 four       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5
#
#          preice_uz
# index
# 0      148593445.0
# 1      181681500.0
# 2      181681500.0
# 3      153603450.0
# 4      192141950.0

# %%
df['num-of-cylinders']= df['num-of-cylinders'].replace('four', 4)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                    4         NaN             21.0  13495.0          4
# ...

# %%
df.replace('five', 5)
df.replace(dict)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#        num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                     4         NaN             21.0  13495.0          4
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', index_col="country")
df2.head()
# Out:
#          rank     density   densityMi    pop2021   area
# country
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2
# Burundi    28    440.3044   1140.3884  12255.433  27834
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2

# %%
df2.rename(index=str.upper)
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(index=str.upper, columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(columns={'pop2021':'population'}) # rename nomni o'zgartiradi.
df2.rename(index={'Monaco':'Melburn'})
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Melburn              2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Macau                1  21946.4667  56841.3487    658.394       30
# Melburn              2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]
